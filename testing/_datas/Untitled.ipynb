# %%
i = 5.225
f'{i:.2}'
# Out:
# '5.2'

# %%
import time

t0 = time.time()
time.sleep(1)
t1 = time.time()
f'{t1-t0:.2} s'
# Out:
# '1.0 s'

# %%
from time import time as start
start()
# Out:
# 1554829471.8348277

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.ion()
fig, ax = plt.subplots()

ax.set_xlabel('test')
plt.ticklabel_format(style = 'sci', axis = 'y', scilimits = (0, 0))
ax.plot(np.arange(1000))

# %%
import pyqtgraph as pg
import numpy as np
x = np.arange(1000)
y = np.arange(1000)
pg.plot(x, y)

# %%
## build a QApplication before building other widgets
import pyqtgraph as pg
pg.mkQApp()

## make a widget for displaying 3D objects
import pyqtgraph.opengl as gl
view = gl.GLViewWidget()
view.show()

## create three grids, add each to the view
xgrid = gl.GLGridItem()
ygrid = gl.GLGridItem()
zgrid = gl.GLGridItem()
view.addItem(xgrid)
view.addItem(ygrid)
view.addItem(zgrid)

## rotate x and y grids to face the correct direction
xgrid.rotate(90, 0, 1, 0)
ygrid.rotate(90, 1, 0, 0)

## scale each grid differently
xgrid.scale(0.2, 0.1, 0.1)
ygrid.scale(0.2, 0.1, 0.1)
zgrid.scale(0.1, 0.2, 0.1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-122-4e9722abd597> in <module>()
#       4
#       5 ## make a widget for displaying 3D objects
# ----> 6 import pyqtgraph.opengl as gl
#       7 view = gl.GLViewWidget()
#       8 view.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyqtgraph\opengl\__init__.py in <module>()
# ----> 1 from .GLViewWidget import GLViewWidget
#       2
#       3 ## dynamic imports cause too many problems.
#       4 #from .. import importAll
#       5 #importAll('items', globals(), locals())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyqtgraph\opengl\GLViewWidget.py in <module>()
#       1 from ..Qt import QtCore, QtGui, QtOpenGL, USE_PYQT5
# ----> 2 from OpenGL.GL import *
#       3 import OpenGL.GL.framebufferobjects as glfbo
#       4 import numpy as np
#       5 from .. import Vector
#
# ModuleNotFoundError: No module named 'OpenGL'

# %%
def _():
    import numpy
