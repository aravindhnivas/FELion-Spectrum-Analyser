# %%
import json, numpy as np

# %%
data = {
    "mass":[[1, 2, 3], [1, 2, 3], [1, 2, 3]],
    "counts":[[0, 100, 50], [1, 2, 3], [1, 2, 3]]
}

# %%
json.dumps(data)
# Out:
# '{"data_0": {"x": [0.6893170494234432, 0.014220957956454394, 0.3459075518052598, 0.10917360228961104, 0.4507221421136496, 0.939993993807991, 0.2842429344844054, 0.9908726903734711, 0.13458517917168078, 0.9058012644934809, 0.4687563293273037, 0.33345162066935585, 0.8433313784692279, 0.7226899834389136, 0.6955382733709614, 0.17922248064749036, 0.988144219584065, 0.3003244695947944, 0.8998446694174922, 0.8673001098826354], "y": [0.4192432136560791, 0.6837401653166084, 0.8537512266725986, 0.0004917675728138837, 0.250088973077204, 0.35306294543365213, 0.16041902172903466, 0.2857584372727726, 0.7903863762855664, 0.6268900188564411, 0.7438144934514224, 0.7324357400023384, 0.15008509181662288, 0.41050830251338166, 0.0011939885103204873, 0.09898629586209262, 0.395011331684028, 0.37436647789975386, 0.44283605109832336, 0.695696872405881]}}'

# %%
tempx = np.random.rand(3, 20).tolist()
tempy = np.random.rand(3, 20).tolist()

# %%
data = {}
i = 0
for x, y in zip(tempx, tempy):
    data[f"data_{i}"] = {"x":x, "y":y}
data
# Out:
# {'data_0': {'x': [0.9610932069645705,
#    0.793309280293118,
#    0.22826464557631632,
#    0.1266995747633215,
#    0.9304115703607528,
#    0.7119438288105078,
#    0.12446396701315054,
#    0.5837612104620405,
#    0.9608116196816362,
#    0.1233270932833711,
#    0.12934134532746144,
#    0.3404278231555533,
#    0.7954163790452667,
#    0.2533974122210122,
#    0.9468035004097823,
#    0.06481849730916533,
#    0.3106206669009126,
#    0.4612670792063803,
#    0.4435066451161278,
#    0.5734489230699805],
#   'y': [0.5531783850058658,
#    0.16537764436611258,
#    0.6303267496987324,
#    0.0120371007868455,
#    0.5988166418979384,
#    0.7489611978061566,
#    0.5805614723570848,
#    0.31358845643324895,
#    0.4604763659638398,
#    0.12168009710181904,
#    0.8113892996522735,
#    0.6223234848245586,
#    0.8858514242989665,
#    0.6515869075038141,
#    0.587288637928329,
#    0.16664460229970002,
#    0.48505132520852423,
#    0.6551267157263945,
# ...

# %%
json.dumps(data)
# Out:
# '{"data_0": {"x": [0.9610932069645705, 0.793309280293118, 0.22826464557631632, 0.1266995747633215, 0.9304115703607528, 0.7119438288105078, 0.12446396701315054, 0.5837612104620405, 0.9608116196816362, 0.1233270932833711, 0.12934134532746144, 0.3404278231555533, 0.7954163790452667, 0.2533974122210122, 0.9468035004097823, 0.06481849730916533, 0.3106206669009126, 0.4612670792063803, 0.4435066451161278, 0.5734489230699805], "y": [0.5531783850058658, 0.16537764436611258, 0.6303267496987324, 0.0120371007868455, 0.5988166418979384, 0.7489611978061566, 0.5805614723570848, 0.31358845643324895, 0.4604763659638398, 0.12168009710181904, 0.8113892996522735, 0.6223234848245586, 0.8858514242989665, 0.6515869075038141, 0.587288637928329, 0.16664460229970002, 0.48505132520852423, 0.6551267157263945, 0.48955499403105684, 0.572301707468344]}}'

# %%
from pathlib import Path as pt
