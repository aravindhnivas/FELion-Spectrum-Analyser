# %%
from glob2 import glob as find
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
location = 'D:\\FELion-Spectrum-Analyser\\testing\\_datas'
os.chdir(location)

# %%
find('*.mass')
# Out:
# ['01_06_18-1.mass',
#  '04_06_18-1.mass',
#  '04_06_18-2.mass',
#  '07_03_19-7.mass',
#  '19_11_18-5.mass',
#  '21_11_18-10.mass',
#  'massScan.mass']

# %%
file = 'massScan.mass'
data = np.genfromtxt(file)
x, y = data[:,0], data[:,1]
fig, ax = plt.subplots()

ax.plot(x, y, label = f'{file}')
ax.set_yscale('log')
ax.grid(True)
ax.legend()

# %%
name = input('Please enter your name: ')
print(f'Welcome {name}.')
# Out:
# Please enter your name:  John
# Welcome John.
