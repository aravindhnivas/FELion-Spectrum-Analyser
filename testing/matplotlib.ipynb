# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, axs = plt.subplots(3,3)
plt.tight_layout()
for i,j in enumerate(axs.flat): print(i,j)
# Out:
# 0 AxesSubplot(0.0779514,0.738194;0.228675x0.210417)
# 1 AxesSubplot(0.402951,0.738194;0.228675x0.210417)
# 2 AxesSubplot(0.727951,0.738194;0.228675x0.210417)
# 3 AxesSubplot(0.0779514,0.417361;0.228675x0.210417)
# 4 AxesSubplot(0.402951,0.417361;0.228675x0.210417)
# 5 AxesSubplot(0.727951,0.417361;0.228675x0.210417)
# 6 AxesSubplot(0.0779514,0.0965278;0.228675x0.210417)
# 7 AxesSubplot(0.402951,0.0965278;0.228675x0.210417)
# 8 AxesSubplot(0.727951,0.0965278;0.228675x0.210417)

# %%
ax1=plt.subplot2grid((3,3),(1,0), colspan=2, rowspan=2)
ax2=plt.subplot2grid((3,3),(1,2), colspan=1, rowspan=2)
ax2=plt.subplot2grid((3,3),(0,0), colspan=3, rowspan=1)
plt.tight_layout()

# %%
import matplotlib.gridspec as gridspec

gs = gridspec.GridSpec(3, 3)
#gs.update(left=0.05, right=0.48, wspace=0.05)

ax1 = plt.subplot(gs[0, :])
ax2 = plt.subplot(gs[1, :-1])
ax3 = plt.subplot(gs[1:, -1])
ax4 = plt.subplot(gs[-1, 0])
ax5 = plt.subplot(gs[-1, -2])

plt.tight_layout()

# %%
gs = gridspec.GridSpec(2,2,
                       width_ratios=[1, 2],
                       height_ratios=[1, 1]
                       )

ax1 = plt.subplot(gs[0])
ax2 = plt.subplot(gs[1])
ax3 = plt.subplot(gs[2])
ax4 = plt.subplot(gs[3])
plt.tight_layout()
