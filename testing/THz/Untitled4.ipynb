# %%
import matplotlib.pyplot as plt
import numpy as np
import datetime
import matplotlib.dates as mdates
from matplotlib.transforms import Transform
from matplotlib.ticker import (
    AutoLocator, AutoMinorLocator)
# %matplotlib inline

# %%
fig = plt.figure(dpi=100)

ax0 = fig.add_subplot(2, 3, 1)
ax1 = fig.add_subplot(232, sharey=ax0)
ax2 = fig.add_subplot(233)

ax3 = fig.add_subplot(234, sharex=ax0)
ax4 = fig.add_subplot(235, sharey=ax3)
ax5 = fig.add_subplot(236)

ax0.plot([1, 2, 5], [1, 2, 3])
ax1.plot([1, 2, 3], [1, 2, 20])
ax2.plot([1, 2, 20], [1, 2, 1])

ax3.plot([1, 2, 3], [1, 2, 1])
ax4.plot([1, 2, 3], [1, 2, 20])
ax5.plot([1, 2, 3], [1, 2, 5])

ax1.set_yticklabels([])

plt.tight_layout()

# %%
plt.close('all')
