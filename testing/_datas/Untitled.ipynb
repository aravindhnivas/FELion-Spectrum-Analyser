# %%
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
temp = 'k1*m25.8*'
sys.argv
# Out:
# ['C:\\ProgramData\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py',
#  '-f',
#  'C:\\Users\\admin-bruenken\\AppData\\Roaming\\jupyter\\runtime\\kernel-02b499fa-deab-40e8-af81-a08db44fd883.json']

# %%
from scitools.StringFunction import StringFunction
temp = {'25.8':1000}
formula = "temp['25.8'] + exp(x) * sin(x) + y - z"
variables = 'x, y, z'
f = StringFunction(formula, independent_variable = variables, temp = temp)
f(0, 1, -1), eval("temp['25.8']")
# Out:
# (1002.0, 1000)

# %%
a = 2.1
temp1 = {}
temp1[f'a'] = 0
temp1
# Out:
# {'a': 0}

# %%
f1 = "test = temp['25.8'] + exp(x) * sin(x) + y - z, (x, y, z)"
formula = f1.split(',')[0].split('=')[1].strip()
fit_mass = f1.split(',')[0].split('=')[0].strip()
var = f1.split(',')[1:]
formula, fit_mass, var
# Out:
# ("temp['25.8'] + exp(x) * sin(x) + y - z", 'test', [' (x', ' y', ' z)'])

# %%
var = 'x, y, z'
var.split(',')
# Out:
# ['x', ' y', ' z']

# %%
import itertools as it
x = it.count(0.05, step=0.05)
print(next(x))
print(next(x))
print(next(x))
print(next(x))
print(next(x))
print(next(x))
print(next(x))
# Out:
# 0.05
# 0.1
# 0.15000000000000002
# 0.2
# 0.25
# 0.3
# 0.35

# %%
for i in range(11):
    locals()[f'y{i}'] = i
y0, y1, y9, y10
# Out:
# (0, 1, 9, 10)
